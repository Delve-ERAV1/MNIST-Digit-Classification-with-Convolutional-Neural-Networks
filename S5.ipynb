# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/ERAv1
# Out:
# /content/drive/MyDrive/ERAv1

# %%
from model import *
from utils import *
import torch.optim as optim
# Out:
# CUDA Available? True
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 32, 26, 26]             320
#             Conv2d-2           [-1, 64, 24, 24]          18,496
#             Conv2d-3          [-1, 128, 10, 10]          73,856
#             Conv2d-4            [-1, 256, 8, 8]         295,168
#             Linear-5                   [-1, 50]         204,850
#             Linear-6                   [-1, 10]             510
# ================================================================
# Total params: 593,200
# Trainable params: 593,200
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.67
# Params size (MB): 2.26
# Estimated Total Size (MB): 2.94
# ----------------------------------------------------------------

# %%
# Download train & test data
train_loader, test_loader = get_data()

# %%
# Plot Sample Data
make_viz(train_loader)

# %%
model = Net().to(device)
optimizer = optim.SGD(model.parameters(), lr=0.01, momentum=0.9)
scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=15, gamma=0.1, verbose=True)

# New Line
criterion = nn.CrossEntropyLoss()
num_epochs = 20

for epoch in range(1, num_epochs+1):
  print(f'Epoch {epoch}')
  train(model, device, train_loader, optimizer, criterion)
  test(model, device, train_loader, criterion)
  scheduler.step()
# Out:
# Adjusting learning rate of group 0 to 1.0000e-02.
# Epoch 1
# Train: Loss=0.4896 Batch_id=117 Accuracy=45.95: 100%|██████████| 118/118 [00:23<00:00,  5.01it/s]
# Test set: Average loss: 0.0009, Accuracy: 51920/60000 (86.53%)
#
# Adjusting learning rate of group 0 to 1.0000e-02.
# Epoch 2
# Train: Loss=0.2862 Batch_id=117 Accuracy=92.75: 100%|██████████| 118/118 [00:23<00:00,  4.95it/s]
# Test set: Average loss: 0.0003, Accuracy: 57278/60000 (95.46%)
#
# Adjusting learning rate of group 0 to 1.0000e-02.
# Epoch 3
# Train: Loss=0.2598 Batch_id=117 Accuracy=95.92: 100%|██████████| 118/118 [00:23<00:00,  4.92it/s]
# Test set: Average loss: 0.0002, Accuracy: 57954/60000 (96.59%)
#
# Adjusting learning rate of group 0 to 1.0000e-02.
# Epoch 4
# Train: Loss=0.2016 Batch_id=117 Accuracy=96.98: 100%|██████████| 118/118 [00:22<00:00,  5.27it/s]
# Test set: Average loss: 0.0002, Accuracy: 58343/60000 (97.24%)
#
# Adjusting learning rate of group 0 to 1.0000e-02.
# Epoch 5
# Train: Loss=0.1945 Batch_id=117 Accuracy=97.35: 100%|██████████| 118/118 [00:22<00:00,  5.28it/s]
# Test set: Average loss: 0.0002, Accuracy: 58454/60000 (97.42%)
#
# Adjusting learning rate of group 0 to 1.0000e-02.
# Epoch 6
# Train: Loss=0.2074 Batch_id=117 Accuracy=97.67: 100%|██████████| 118/118 [00:23<00:00,  5.01it/s]
# Test set: Average loss: 0.0001, Accuracy: 58744/60000 (97.91%)
#
# Adjusting learning rate of group 0 to 1.0000e-02.
# Epoch 7
# Train: Loss=0.1511 Batch_id=117 Accuracy=97.95: 100%|██████████| 118/118 [00:23<00:00,  4.96it/s]
# Test set: Average loss: 0.0001, Accuracy: 58825/60000 (98.04%)
#
# Adjusting learning rate of group 0 to 1.0000e-02.
# Epoch 8
# Train: Loss=0.1657 Batch_id=117 Accuracy=98.08: 100%|██████████| 118/118 [00:23<00:00,  4.94it/s]
# Test set: Average loss: 0.0001, Accuracy: 58743/60000 (97.91%)
#
# Adjusting learning rate of group 0 to 1.0000e-02.
# Epoch 9
# Train: Loss